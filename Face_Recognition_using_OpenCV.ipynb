# %% [markdown]
# <a href="https://colab.research.google.com/github/charlie-aashutosh/Deep-Learning/blob/master/Face_Recognition_using_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/test1.jpg')

# %%
print(cv2_imshow(img))
# Out:
# <PIL.Image.Image image mode=RGB size=816x1055 at 0x7FE4F281CD30>
# None

# %%
img
# Out:
# array([[[236, 220, 197],
#         [236, 220, 197],
#         [237, 220, 199],
#         ...,
#         [237, 218, 203],
#         [237, 218, 203],
#         [237, 218, 203]],
#
#        [[235, 219, 196],
#         [236, 220, 197],
#         [236, 219, 198],
#         ...,
#         [237, 218, 203],
#         [237, 218, 203],
#         [237, 218, 203]],
#
#        [[235, 218, 197],
#         [236, 219, 198],
#         [236, 219, 198],
#         ...,
#         [237, 218, 203],
#         [237, 218, 203],
#         [237, 218, 203]],
#
#        ...,
#
#        [[229, 216, 200],
#         [230, 217, 201],
#         [231, 221, 204],
#         ...,
#         [231, 211, 194],
#         [228, 208, 191],
#         [226, 206, 189]],
#
#        [[229, 216, 200],
#         [230, 217, 201],
#         [231, 221, 204],
#         ...,
#         [230, 210, 193],
#         [228, 208, 191],
#         [226, 206, 189]],
#
#        [[229, 216, 200],
#         [230, 217, 201],
#         [231, 221, 204],
# ...

# %%
img.shape
# Out:
# (1055, 816, 3)

# %%
img1=cv2.imread('/content/test1.jpg',0)

# %%
print(cv2_imshow(img1))
# Out:
# <PIL.Image.Image image mode=L size=816x1055 at 0x7FE4F1F994A8>
# None

# %%
img1.shape
# Out:
# (1055, 816)

# %%
#converting image to HSV format
new_img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=816x1055 at 0x7FE4F1F995F8>

# %%
new_img.shape
# Out:
# (1055, 816, 3)

# %%
#resizing image
small_img=cv2.resize(img,(200,200))

# %%
cv2_imshow(small_img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FE4F1F995C0>

# %%
gray_image=img1

# %%
#using different threshold styles for our grayscale image
ret,thresh_binary = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
ret,thresh_binary_inv=cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc=cv2.threshold(gray_image,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero=cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO)
ret,thresh_tozero_inv=cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO_INV)

# %%
#displaying different thresholding styles
names=['Original_image','Binary','Thresh_Binary','Thresh_Trunc','Thresh_Tozero','Thresh_Tozero_Inv']

images=gray_image,thresh_binary,thresh_binary_inv,thresh_tozero,thresh_tozero_inv

for i in range(5):
  plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')

  plt.title(names[i])
  plt.xticks([]),plt.yticks([])

# %%
##FACE RECOGNITION

# %%
face_cascade=cv2.CascadeClassifier('/content/haarcascade_frontalface_alt.xml')

# %%
faces=face_cascade.detectMultiScale(gray_image,1.1,4)

# %%
#drawing rectangles around the face
for(x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

#displaying our output
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=816x1055 at 0x7FE4F1F99BE0>
# -1
